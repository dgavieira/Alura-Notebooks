# %% [markdown]
# # Caracterização dos Dados

# %% [markdown]
# [É gordinho?, Tem perinha Curta?, Faz AuAu?]

# %%
porco1 =    [1,1,0]
porco2 =    [1,1,0]
porco3 =    [1,1,0]
cachorro1 = [1,1,1]
cachorro2 = [0,1,1]
cachorro3 = [0,1,1]

# %% [markdown]
# # Concatenando dados de treinamento em um conjunto

# %%
dados = [porco1, porco2, porco3, cachorro1, cachorro2, cachorro3]

# %% [markdown]
# * porco -> 1
# * cachorro -> -1

# %%
marcacoes = [1,1,1,-1,-1,-1]

# %% [markdown]
# # Colocando dados para teste

# %%
misterioso1 = [1,1,1]
misterioso2 = [1,0,0]
misterioso3 = [0,0,1]

# %%
teste = [misterioso1, misterioso2, misterioso3]
marcacoes_teste = [-1,1,-1]

# %% [markdown]
# # Realizando Treinamento

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
modelo = MultinomialNB()
modelo.fit(dados, marcacoes)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# # Obtendo Predições

# %%
resultado = modelo.predict(teste)
resultado
# Out:
# array([-1,  1, -1])

# %% [markdown]
# * onde acertou = printa 0
# * onde errou = printa outro valor

# %%
diferencas = resultado - marcacoes_teste
print(diferencas)
# Out:
# [0 0 0]

# %%
acertos = [d for d in diferencas if d==0]
print(acertos)
total_de_acertos = len(acertos)
print("Total de acertos: {}".format(total_de_acertos))
total_de_elementos = len(teste)
print("Total de elementos: {}".format(total_de_elementos))
taxa_de_acerto = 100.0 * (total_de_acertos/total_de_elementos)
print("Taxa de acerto: {}%".format(taxa_de_acerto))
# Out:
# [0, 0, 0]
# Total de acertos: 3
# Total de elementos: 3
# Taxa de acerto: 100.0%
