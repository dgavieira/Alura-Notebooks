# %%
import tweepy as tw

# %%
consumer_key = 'Td2TtTZKbP7jeZ6DUerhoYUWC'
consumer_secret = 'aW6Ha0RGWHqIzCcqKQeiH6z7ovIERDNUDDzMpAYYMQ2Kt2QlDe'
access_token = '122192790-oBdWkEzxG3FntkeRbRDpMAWJo44COFxt5dlL5hw0'
access_token_secret = 'a4zFSxni1SXlluJaPWAuNqvfE5p2F6xNizOm4RXly9ty1'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth)

# %%
#tweet = api.update_status("Esse sofrimento do caralho ano que vem é o vasco")

# %% [markdown]
# # Pesquisando Tweets

# %%
tweets = tw.Cursor(api.search,
          q="vasco",
          since='2019-01-01',
          lang='pt').items(20)

# %%
for tweet in tweets:
  print(tweet.user.screen_name)
  print(tweet.user.location)
  print(tweet.text)
  print('-----')
  print('\n')

# %%
famosos = ['cauareymond','aguiarthur','ivetesangalo','ClaudiaLeitte','neymarjr','BruMarquezine','mariruybarbosa',
'FePaesLeme','Tatawerneck','FlaviaAleReal','julianapaes','dedesecco','SabrinaSato','ahickmann','gusttavo_lima','Anitta',
'CarolCastroReal','gio_antonelli','maisa','cleooficial','gewbank','taisdeverdade','otaviano','bernardipaloma',
'IngridGuimaraes','olazaroramos','GalisteuOficial','debranascimento','FioMattheis','moalfradique','Nandacostareal']

# %%
len(famosos)
# Out:
# 31

# %%
for famoso in famosos:
  tweets = tw.Cursor(api.search,
                     q=famoso,
                     since='2019-01-01').items(20)

  for tweet in tweets:
    if 'media' in tweet.entities:
      print(tweet.entities['media'][0]['media_url'])
    
  print('-----')
  print('\n')

# %% [markdown]
# # Streaming

# %%
class MinhaStreamListener(tw.StreamListener):

  def on_status(self, status):
    print(status.user.screen_name)
    print(status.text)
    print('------')
    print('\n')

# %%
minhaStream = tw.Stream(auth = auth, listener=MinhaStreamListener())

# %%
minhaStream.filter(track=famosos)
# Out:
# DoceDaJuliette
# @acessojuliette Dezessete
# #MPN #Anitta #GirlFromRio #Plinio #Cactos #JulietteCriadora #JulietteFashion #KCAMexico… https://t.co/Di2vANPKNe
# ------
#
#
# cactogringa
# @acessojuliette uno #MPN #Anitta #GirlFromRio #Plinio #Cactos #JulietteCriadora #JulietteFashion #KCAMexico… https://t.co/7tqS4t4o1G
# ------
#
#
# gabxxis
# @acessojuliette #MPN #Anitta #GirlFromRio #Plinio #JulietteFashion #JulietteCriadora #Cactos #KCAMexico #KeniaOs… https://t.co/V1w4NfK8kx
# ------
#
#
# pricatsjc
# @centralfreirebr L #MPN #Anitta #GirlFromRio #Plinio #Cactos #JulietteCriadora #JulietteFashion #KCAMexico … https://t.co/F5LxuciI9Q
# ------
#
#
# miojocacto
# @acessojuliette Quatroze #MPN #Anitta #GirlFromRio #Plinio #Cactos #JulietteCriadora #JulietteFashion #KCAMexico … https://t.co/7l9v0ypTUT
# ------
#
#
# Alan33288449
# @acessojuliette 36 Respondam usando: #MPN #Anitta #GirlFromRio #Plinio #Cactos #JulietteCriadora #JulietteFashion… https://t.co/fHcvmyy2oR
# ------
#
#
# ...

# %% [markdown]
# # Computer Vision API

# %%
pip install azure-cognitiveservices-vision-computervision
# Out:
# ...
#      |████████████████████████████████| 85 kB 2.3 MB/s
# ...
#      |████████████████████████████████| 45 kB 3.4 MB/s
# ...

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

# %%
key_1 = "bdbb1d7135834968bc181a21a4e7c167"
credenciais = CognitiveServicesCredentials(key_1)

# %%
 endpoint = "https://diego-cpu.cognitiveservices.azure.com/"
 client = ComputerVisionClient(endpoint, credenciais)

# %%
client.api_version
# Out:
# '3.2'

# %%
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes
url = "https://pbs.twimg.com/media/E9P8CaIWUAADIEb.jpg"

analise_de_imagem = client.analyze_image(url, VisualFeatureTypes.tags)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: 'T' is not a valid VisualFeatureTypes
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/msrest/serialization.py in serialize_enum(attr, enum_obj)
#     998         try:
# --> 999             enum_obj(result)
#    1000             return result
#
# /usr/lib/python3.7/enum.py in __call__(cls, value, names, module, qualname, type, start)
#     314         if names is None:  # simple value lookup
# --> 315             return cls.__new__(cls, value)
#     316         # otherwise, functional API: we're creating a new Enum type
#
# /usr/lib/python3.7/enum.py in __new__(cls, value)
#     568             exc.__context__ = ve_exc
# --> 569             raise exc
#     570
#
# ...
